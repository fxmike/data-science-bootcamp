# %% [markdown]
# <a href="https://colab.research.google.com/github/fxmike/data-science-bootcamp/blob/main/05_p_stwo_statystyka/01_p_stwo_statystyka.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
X = np.array([3, 4.5, 5, 4.5, 3])
print(X)
# Out:
# [3.  4.5 5.  4.5 3. ]

# %% [markdown]
# statystyka opisowa - miary tendencji centralnej

# %% [markdown]
# średnia arytmetyczna

# %%
X.mean()
# Out:
# 4.0

# %% [markdown]
# ![Zrzut ekranu 2021-05-24 125432.png](data:image/png;base64,...)

# %% [markdown]
# mediana

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
np.median(X)
# Out:
# 4.5

# %%
X=np.array([3,4.5,5,5])

# %%
np.median(X)
# Out:
# 4.75

# %% [markdown]
# moda - najczęściej występująca wartość w ciągu

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# statystyka opisowa - miary rozrzutu

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
X = [3.5, 4, 4]
Y = [2, 4, 5]

X_mean = np.mean(X)
Y_mean = np.mean(Y)

# %%
b_X = 1 / len(X) * (abs(X-X_mean).sum())
b_Y = 1 / len(Y) * (abs(Y-Y_mean).sum())

# %%
b_X.round(2)
# Out:
# 0.22

# %%
b_Y.round(2)
# Out:
# 1.11

# %% [markdown]
# wariancja
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# odchylenie standardowe ![image.png](data:image/png;base64,...)

# %%
 var_X = 1/ len(X) * ((X- X_mean)**2).sum()
 var_Y = 1/ len(X) * ((Y- Y_mean)**2).sum()

 print(var_X.round(4))
 print(var_Y.round(4))
# Out:
# 0.0556
# 1.5556

# %%
std_X = np.sqrt(var_X)
std_Y = np.sqrt(var_Y)

print(std_X.round(4))
print(std_Y.round(4))
# Out:
# 0.2357
# 1.2472

# %%
np.std(X)
# Out:
# 0.23570226039551584

# %% [markdown]
# dystrybuanta empiryczna;
#
# kwantylem rzędu p zmiennej losowej X nazywamy wartość, która dzieli uporządkowany ciąg wartości x1,...,xn na dwie części w proporcjach p oraz 1-p

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
omega = {1,2,3,4,5,6}

A = {item for item in omega if item % 2 == 0}

P_A = len(A) / len(omega)
print(f'Zbiór A: {A}')
print(f'Prawd zdarzenia A: {P_A}')
# Out:
# Zbiór A: {2, 4, 6}
# Prawd zdarzenia A: 0.5

# %%
omega = {1,2,3,4,5,6}

B = {item for item in omega if item > 4}

P_B = len(B) / len(omega)
print(f'Zbiór A: {B}')
print(f'Prawd zdarzenia A: {P_B:.4f}')
# Out:
# Zbiór A: {5, 6}
# Prawd zdarzenia A: 0.3333

# %% [markdown]
# ![image.png](data:image/png;base64,...) // kiedy prawdopodobieństwo iloczynu jest równe iloczynowi prawdopodobieństw

# %%
intersection_AB = set.intersection(A, B)
P_intersection_AB = len(intersection_AB) / len(omega)

PA_PB = P_A * P_B

print(f'Przecięcie zbiorów A i B: {intersection_AB}\n')
print(f'Iloczyn prawdopodobieństw zdarzeń A i B: {PA_PB:.4f}')
print(f'Prawdopodobieństwo iloczynu zdarzeń A i B: {P_intersection_AB:.4f}\n')

check = 'Zdarzenia niezależne' if PA_PB == P_intersection_AB else 'Zdarzenia zależne'
print(check)
# Out:
# Przecięcie zbiorów A i B: {6}
#
# Iloczyn prawdopodobieństw zdarzeń A i B: 0.1667
# Prawdopodobieństwo iloczynu zdarzeń A i B: 0.1667
#
# Zdarzenia niezależne

# %%
omega = {1,2,3,4,5,6}

C = {item for item in omega if item > 1}

P_C = len(C) / len(omega)
print(f'Zbiór A: {C}')
print(f'Prawd zdarzenia A: {P_C:.4f}')

intersection_AC = set.intersection(A, C)
P_intersection_AC = len(intersection_AC) / len(omega)

PA_PC = P_A * P_C

print(f'Przecięcie zbiorów A i B: {intersection_AC}\n')
print(f'Iloczyn prawdopodobieństw zdarzeń A i B: {PA_PC:.4f}')
print(f'Prawdopodobieństwo iloczynu zdarzeń A i B: {P_intersection_AC:.4f}\n')

check = 'Zdarzenia niezależne' if PA_PC == P_intersection_AC else 'Zdarzenia zależne'
print(check)
# Out:
# Zbiór A: {2, 3, 4, 5, 6}
# Prawd zdarzenia A: 0.8333
# Przecięcie zbiorów A i B: {2, 4, 6}
#
# Iloczyn prawdopodobieństw zdarzeń A i B: 0.4167
# Prawdopodobieństwo iloczynu zdarzeń A i B: 0.5000
#
# Zdarzenia zależne

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(A)
print(B)
print(intersection_AB)
# Out:
# {2, 4, 6}
# {5, 6}
# {6}

# %%
PA_cond_B = P_intersection_AB / P_B

# %%
print(PA_cond_B)
# Out:
# 0.5

# %% [markdown]
# Zmienna Losowa

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#wartość oczekiwana
EX = 0 * 0.5 + 1 * 0.3 + 2 * 0.15 + 3 * 0.05
EX
# Out:
# 0.75

# %%
#wariancja
VAR_X = (0 - EX)**2 * 0.5 + (1 - EX)**2 * 0.3 + (2 - EX)**2 * 0.15 + (3 -EX)**2 * 0.05
VAR_X
# Out:
# 0.7875000000000001

# %%
#odchylenie standardowe
import numpy as np

STD_X = np.sqrt(VAR_X)
STD_X

#średnio klient robi 3/4 zdarzenia na rok z odychleniem 0.88
# Out:
# 0.8874119674649424

# %%
x = np.random.randn(5)
y = np.random.randn(5)

print(x, y)
# Out:
# [ 0.56749371 -2.28514642  0.60146373  0.56186166 -1.53367745] [ 0.61894102 -0.22719947 -0.15102575  1.6810839  -1.53448505]

# %%
x.mean()
# Out:
# -0.41760095511800566

# %%
x.std()
# Out:
# 1.2410966242110613

# %%
#macierz korelacji zmiennych
np.corrcoef(x ,y)
# Out:
# array([[1.        , 0.64504415],
#        [0.64504415, 1.        ]])

# %% [markdown]
# Rozkład normalny
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# N(mi, sigma).
# mi - wartość oczekiwana
# sigma - odchylenie standardowe

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
sns.set()

mu = 0 # wartość oczekiwana
sigma = 1 # odchylenie standardowe
x = np.linspace(mu - 3 * sigma, mu + 3 * sigma, 100)
plt.title('Rozkład normalny - funkcja gęstości')
plt.plot(x, norm.pdf(x, mu, sigma))

# %%
x = np.linspace(mu - 3 * sigma, mu + 3 * sigma, 500)
params = [(0,1), (0,2), (0,0.5)]
plt.figure(figsize= (12, 8))

for mu, sigma in params:
  plt.plot(x, norm.pdf(x, mu, sigma), label=f'mu={mu}, sigma={sigma}')

plt.legend()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
mu = 10 
sigma = 3
x = np.linspace(mu - 8 * sigma, mu + 8 * sigma, 500)


plt.plot(x, norm.pdf(x, mu, sigma), label=f'mu={mu}, sigma={sigma}')
plt.plot(x, norm.pdf(x, mu - mu, sigma), label=f'mu={mu - mu}, sigma={sigma}')
plt.plot(x, norm.pdf(x, mu - mu, sigma / sigma), label=f'mu={mu - mu}, sigma={sigma / sigma}')
plt.legend()

# %% [markdown]
# Wykres dystrybuanty

# %%
plt.title('Rozkład normany - dystrybuanta')
plt.plot(x, norm.cdf(x, mu, sigma))
#prawdopodobieństwo, że zmienna x jest mniejsza lub równa dla każdego punktu w rozkładzie

# %%
plt.title('Rozkład normalny - funkcja przeżycia')
plt.plot(x, norm.sf(x, mu, sigma))

# %%
from scipy import stats
dir(stats)
# Out:
# ['PearsonRConstantInputWarning',
#  'PearsonRNearConstantInputWarning',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_binned_statistic',
#  '_constants',
#  '_continuous_distns',
#  '_discrete_distns',
#  '_distn_infrastructure',
#  '_distr_params',
#  '_hypotests',
#  '_multivariate',
#  '_rvs_sampling',
#  '_stats',
#  '_stats_mstats_common',
#  '_tukeylambda_stats',
#  'absolute_import',
#  'alpha',
#  'anderson',
#  'anderson_ksamp',
#  'anglit',
#  'ansari',
#  'arcsine',
#  'argus',
#  'bartlett',
#  'bayes_mvs',
#  'bernoulli',
#  'beta',
#  'betabinom',
#  'betaprime',
#  'binned_statistic',
#  'binned_statistic_2d',
#  'binned_statistic_dd',
#  'binom',
#  'binom_test',
#  'boltzmann',
#  'boxcox',
#  'boxcox_llf',
#  'boxcox_normmax',
#  'boxcox_normplot',
#  'bradford',
#  'brunnermunzel',
#  'burr',
#  'burr12',
#  'cauchy',
#  'chi',
#  'chi2',
#  'chi2_contingency',
#  'chisquare',
#  'circmean',
#  'circstd',
#  'circvar',
#  'combine_pvalues',
#  'contingency',
#  'cosine',
#  'crystalball',
#  'cumfreq',
#  'describe',
#  'dgamma',
#  'dirichlet',
#  'distributions',
#  'division',
#  'dlaplace',
#  'dweibull',
#  'energy_distance',
#  'entropy',
#  'epps_singleton_2samp',
#  'erlang',
#  'expon',
#  'exponnorm',
#  'exponpow',
#  'exponweib',
#  'f',
#  'f_oneway',
#  'fatiguelife',
#  'find_repeats',
#  'fisher_exact',
#  'fisk',
#  'fligner',
#  'foldcauchy',
#  'foldnorm',
#  'frechet_l',
#  'frechet_r',
#  'friedmanchisquare',
#  'gamma',
#  'gausshyper',
#  'gaussian_kde',
#  'genexpon',
#  'genextreme',
#  'gengamma',
#  'genhalflogistic',
#  'geninvgauss',
#  'genlogistic',
#  'gennorm',
#  'genpareto',
#  'geom',
#  'gilbrat',
#  'gmean',
#  'gompertz',
#  'gstd',
#  'gumbel_l',
#  'gumbel_r',
#  'halfcauchy',
#  'halfgennorm',
#  'halflogistic',
#  'halfnorm',
#  'hmean',
#  'hypergeom',
#  'hypsecant',
#  'invgamma',
#  'invgauss',
#  'invweibull',
#  'invwishart',
#  'iqr',
#  'itemfreq',
#  'jarque_bera',
#  'johnsonsb',
#  'johnsonsu',
#  'kappa3',
#  'kappa4',
#  'kde',
#  'kendalltau',
#  'kruskal',
#  'ks_2samp',
#  'ksone',
#  'kstat',
#  'kstatvar',
#  'kstest',
#  'kstwobign',
#  'kurtosis',
#  'kurtosistest',
#  'laplace',
#  'levene',
#  'levy',
#  'levy_l',
#  'levy_stable',
#  'linregress',
#  'loggamma',
#  'logistic',
#  'loglaplace',
#  'lognorm',
#  'logser',
#  'loguniform',
#  'lomax',
#  'mannwhitneyu',
#  'matrix_normal',
#  'maxwell',
#  'median_absolute_deviation',
#  'median_test',
#  'mielke',
#  'mode',
#  'moment',
#  'mood',
#  'morestats',
#  'moyal',
#  'mstats',
#  'mstats_basic',
#  'mstats_extras',
#  'multinomial',
#  'multiscale_graphcorr',
#  'multivariate_normal',
#  'mvn',
#  'mvsdist',
#  'nakagami',
#  'nbinom',
#  'ncf',
#  'nct',
#  'ncx2',
#  'norm',
#  'normaltest',
#  'norminvgauss',
#  'obrientransform',
#  'ortho_group',
#  'pareto',
#  'pearson3',
#  'pearsonr',
#  'percentileofscore',
#  'planck',
#  'pointbiserialr',
#  'poisson',
#  'power_divergence',
#  'powerlaw',
#  'powerlognorm',
#  'powernorm',
#  'ppcc_max',
#  'ppcc_plot',
#  'print_function',
#  'probplot',
#  'randint',
#  'random_correlation',
#  'rankdata',
#  'ranksums',
#  'rayleigh',
#  'rdist',
#  'recipinvgauss',
#  'reciprocal',
#  'relfreq',
#  'rice',
#  'rv_continuous',
#  'rv_discrete',
#  'rv_histogram',
#  'rvs_ratio_uniforms',
#  'scoreatpercentile',
#  'sem',
#  'semicircular',
#  'shapiro',
#  'siegelslopes',
#  'sigmaclip',
#  'skellam',
#  'skew',
#  'skewnorm',
#  'skewtest',
#  'spearmanr',
#  'special_ortho_group',
#  'statlib',
#  'stats',
#  't',
#  'test',
#  'theilslopes',
#  'tiecorrect',
#  'tmax',
#  'tmean',
#  'tmin',
#  'trapz',
#  'triang',
#  'trim1',
#  'trim_mean',
#  'trimboth',
#  'truncexpon',
#  'truncnorm',
#  'tsem',
#  'tstd',
#  'ttest_1samp',
#  'ttest_ind',
#  'ttest_ind_from_stats',
#  'ttest_rel',
#  'tukeylambda',
#  'tvar',
#  'uniform',
#  'unitary_group',
#  'variation',
#  'vonmises',
#  'vonmises_line',
#  'wald',
#  'wasserstein_distance',
#  'weibull_max',
#  'weibull_min',
#  'weightedtau',
#  'wilcoxon',
#  'wishart',
#  'wrapcauchy',
#  'yeojohnson',
#  'yeojohnson_llf',
#  'yeojohnson_normmax',
#  'yeojohnson_normplot',
#  'yulesimon',
#  'zipf',
#  'zmap',
#  'zscore']
